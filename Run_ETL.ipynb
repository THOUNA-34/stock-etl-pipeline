# %%
# %pip install yfinance rich plotly kaleido==0.2.1

# %%
import importlib
import datetime

import config
import extract
import validate
import transform
import load
import dashboard
import run_pipeline

importlib.reload(config)
importlib.reload(extract)
importlib.reload(validate)
importlib.reload(transform)
importlib.reload(load)
importlib.reload(dashboard)
importlib.reload(run_pipeline)

print("✅ All modules reloaded")

# %%
run_pipeline.main()

# %%
display(spark.table("stock_facts"))

# %%
fig = dashboard.build_dashboard()

fig.show()
